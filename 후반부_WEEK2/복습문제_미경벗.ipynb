# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
train = pd.read_csv("data/train.csv")

# %%
sns.relplot(data = train, x = 'Age',y = 'PassengerId', hue = 'Survived', aspect = 2)
plt.show()
