# %% [markdown]
# ## Feature Engineering 계획하기
# **특징 선택**
# Pclass(티켓 등급) 선택
# Sex(성별) 선택
# 항구(Embarked) 선택
#
# **특징 생성**
# Age(나이)의 범위 묶기
# Fare(운임)의 범위 묶기
# SibSp(형제자매 수)와 Parch(부모님 수)를 가족수로 합치기
# Cabin(객실) 정보에서 번호만 삭제하고 객실 종류에 해당하는 알파벳만 남기기
# 빈칸은 평균 값으로 대체하기
#
# **특징 추출**
# Name(이름) 삭제
# Ticket(티켓 일련번호) 삭제
# SibSp(형제자매 수), Parch(부모님 수) 삭제
#
# 이번에도 같은 데이터를 가지고 같은 방식으로 Feature Engineering을 진행하지만 엑셀을 사용하지 않고 Pandas로 처리함.

# %%
import pandas as pd

# %%
df = pd.read_csv('data/train.csv')

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# 원하는 열만 보기 -> 대괄호 두개 필요함. 
df[['Sex', 'Age', 'SibSp', 'Parch']].head()
# Out:
#       Sex   Age  SibSp  Parch
# 0    male  22.0      1      0
# 1  female  38.0      1      0
# 2  female  26.0      0      0
# 3  female  35.0      1      0
# 4    male  35.0      0      0

# %%
# testset -> test는 survived 데이터 없음 
df_test = pd.read_csv('data/test.csv')
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### cf) Train set과 Test set 차이
# **Train set**
# 데이터의 특성을 살펴보고 숨겨진 규칙, 패턴을 찾기 위한 훈련용 데이터
# **Test set**
# 찾아낸 패턴이 정말 맞는지 확인하기 위한 시험용 데이터

# %% [markdown]
# ## 비어 있는 모든 값을 채우기
#
# ### Age의 빈칸(NaN)을 평균으로 대체하기

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
# age 빈칸을 평균으로 영구적으로 채우기
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
# age 잘 채워졌는지 확인
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# testset도 age 빈칸 채워주기
df_test['Age'] = df_test['Age'].fillna(df_test['Age'].mean())

# %%
# trainset의 age 범위 묶어주기
# df.loc[조건, 열] = 넣고싶은값

df.loc[df['Age']<10, 'Age'] = 0
df.loc[(df['Age'] >= 10) & (df['Age'] < 20), 'Age'] = 1
df.loc[(df['Age'] >= 20) & (df['Age'] < 30), 'Age'] = 2
df.loc[(df['Age'] >= 30) & (df['Age'] < 40), 'Age'] = 3
df.loc[(df['Age'] >= 40) & (df['Age'] < 50), 'Age'] = 4
df.loc[df['Age'] >= 50, 'Age'] = 5

# %%
# testset의 age 범위 묶어주기
df_test.loc[df_test['Age']<10, 'Age'] = 0
df_test.loc[(df_test['Age'] >= 10) & (df_test['Age'] < 20), 'Age'] = 1
df_test.loc[(df_test['Age'] >= 20) & (df_test['Age'] < 30), 'Age'] = 2
df_test.loc[(df_test['Age'] >= 30) & (df_test['Age'] < 40), 'Age'] = 3
df_test.loc[(df_test['Age'] >= 40) & (df_test['Age'] < 50), 'Age'] = 4
df_test.loc[df_test['Age'] >= 50, 'Age'] = 5

# %% [markdown]
# ### SibSp와 Parch를 더하여 FamilySize 생성

# %%
# trainset에서 가족수(FamilySize) 열 만들기 
df['FamilySize']  = df['SibSp'] + df['Parch']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  2.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  3.0      1
# 2                             Heikkinen, Miss. Laina  female  2.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  3.0      1
# 4                           Allen, Mr. William Henry    male  3.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# 3      0            113803  53.1000  C123        S           1
# ...

# %%
# testset에서도 가족수(FamilySize) 열 만들기 
df_test['FamilySize']  = df_test['SibSp'] + df_test['Parch']
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#    Age  SibSp  Parch   Ticket     Fare Cabin Embarked  FamilySize
# 0  0.0      0      0   330911   7.8292   NaN        Q           0
# 1  0.0      1      0   363272   7.0000   NaN        S           1
# 2  0.0      0      0   240276   9.6875   NaN        Q           0
# 3  0.0      0      0   315154   8.6625   NaN        S           0
# 4  0.0      1      1  3101298  12.2875   NaN        S           2

# %%
# 필요한 열만 선택하기 
train = df[['Survived', 'Sex', 'Age', 'FamilySize']]
test = df[['Sex', 'Age', 'FamilySize']]

train.head()
# Out:
#    Survived     Sex  Age  FamilySize
# 0         0    male  2.0           1
# 1         1  female  3.0           1
# 2         1  female  2.0           0
# 3         1  female  3.0           1
# 4         0    male  3.0           0

# %% [markdown]
# ### 미션1 : Fare의 빈칸(NaN)을 평균으로 대체하기

# %%
df['Fare'] = df['Fare'].fillna(df['Fare'].mean())

# %%
df_test['Fare'] = df_test['Fare'].fillna(df_test['Fare'].mean())

# %% [markdown]
# ### 빈칸 정보, 값 요약 정보 보기

# %%
# 빈칸정보
# isnull: 빈칸을 찾아달라 sum: 빈칸의 총개수를 세달라 -> 0이면 빈칸 없다는 뜻 
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# FamilySize       0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# FamilySize       0
# dtype: int64

# %%
# value_counts : 값 요약
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ### 미션2: Embarked의 빈칸(NaN)을 가장 많이 존재하는 Embarked로 채우기

# %%
df['Embarked'] = df['Embarked'].fillna('S')
df_test['Embarked'] = df_test['Embarked'].fillna('S')

# %%
# embarked 빈칸 없어졌는지 확인
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# FamilySize       0
# dtype: int64

# %%
# train에 추가하기
train = df[['Survived', 'Sex', 'Age', 'FamilySize', 'Fare', 'Embarked']]
test = df[['Sex', 'Age', 'FamilySize', 'Fare', 'Embarked']]
train.head()
# Out:
#    Survived     Sex  Age  FamilySize     Fare Embarked
# 0         0    male  2.0           1   7.2500        S
# 1         1  female  3.0           1  71.2833        C
# 2         1  female  2.0           0   7.9250        S
# 3         1  female  3.0           1  53.1000        S
# 4         0    male  3.0           0   8.0500        S
