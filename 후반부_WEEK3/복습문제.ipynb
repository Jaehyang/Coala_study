# %%
import pandas as pd

# %%
df = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['Fare'] = df['Fare'].fillna(df['Fare'].mean())
df_test['Fare'] = df_test['Fare'].fillna(df_test['Fare'].mean())

# %%
df.loc[df['Fare'] < 10, 'Fare'] = 0
df.loc[(df['Fare'] >= 10) & (df['Fare'] < 20), 'Fare'] = 1
df.loc[(df['Fare'] >= 20) & (df['Fare'] < 30), 'Fare'] = 2
df.loc[(df['Fare'] >= 30) & (df['Fare'] < 50), 'Fare'] = 3
df.loc[(df['Fare'] >= 50) & (df['Fare'] < 70), 'Fare'] = 4
df.loc[df['Fare'] >= 70, 'Fare'] = 5

# %%
df_test.loc[df_test['Fare'] < 10, 'Fare'] = 0
df_test.loc[(df_test['Fare'] >= 10) & (df_test['Fare'] < 20), 'Fare'] = 1
df_test.loc[(df_test['Fare'] >= 20) & (df_test['Fare'] < 30), 'Fare'] = 2
df_test.loc[(df_test['Fare'] >= 30) & (df_test['Fare'] < 50), 'Fare'] = 3
df_test.loc[(df_test['Fare'] >= 50) & (df_test['Fare'] < 70), 'Fare'] = 4
df_test.loc[df_test['Fare'] >= 70, 'Fare'] = 5

# %%
df['Fare'].value_counts()
# Out:
# 0.0    336
# 1.0    179
# 2.0    136
# 5.0    105
# 3.0     79
# 4.0     56
# Name: Fare, dtype: int64

# %%
df.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
facet = sns.FacetGrid(df, hue = 'Survived', aspect = 4)
facet.map(sns.kdeplot, 'Fare')
facet.add_legend()

plt.show()
